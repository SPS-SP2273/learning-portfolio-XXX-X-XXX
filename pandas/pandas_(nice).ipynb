# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Pandas (Nice)</span></div>

# %% [markdown]
# ## 1 Seaborn

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pn
import numpy as np

# %% [markdown]
# ### 1.1 Setting the context

# %%
# Your code here

# %% [markdown]
# ### 1.2 Some Examples

# %%
# Your code here

# %% [markdown]
# ## 2 A few more things

# %% [markdown]
# ### 2.1 Merging dataframes

# %%
# Your code here

# %% [markdown]
# ### 2.2 isin()

# %%
# Your code here

# %% [markdown]
# ## Explore 1 :  Graduate Data

# %%
#1
data = pn.read_csv('graduate-employment-survey-ntu-nus-sit-smu-suss-sutd.csv', encoding='latin-1')
data
# Out:
#       year                                     university  \
# 0     2013               Nanyang Technological University
# 1     2013               Nanyang Technological University
# 2     2013               Nanyang Technological University
# 3     2013               Nanyang Technological University
# 4     2013               Nanyang Technological University
# ...    ...                                            ...
# 1116  2021        Singapore University of Social Sciences
# 1117  2021  Singapore University of Technology and Design
# 1118  2021  Singapore University of Technology and Design
# 1119  2021  Singapore University of Technology and Design
# 1120  2021  Singapore University of Technology and Design
#
#                                              school  \
# 0     College of Business (Nanyang Business School)
# 1     College of Business (Nanyang Business School)
# 2     College of Business (Nanyang Business School)
# 3     College of Business (Nanyang Business School)
# 4                            College of Engineering
# ...                                             ...
# 1116                             School of Business
# 1117                                             na
# 1118                                             na
# 1119                                             na
# 1120                                             na
#
#                                                  degree  \
# 0                              Accountancy and Business
# 1           Accountancy (3-yr direct Honours Programme)
# 2              Business (3-yr direct Honours Programme)
# 3                                Business and Computing
# 4                                 Aerospace Engineering
# ...                                                 ...
# 1116     Bachelor of Science in Supply Chain Management
# 1117  Bachelor of Engineering (Computer Science and ...
# 1118  Bachelor of Engineering (Engineering Product D...
# 1119  Bachelor of Engineering (Engineering Systems a...
# 1120  Bachelor of Science (Architecture and Sustaina...
#
#      employment_rate_overall employment_rate_ft_perm basic_monthly_mean  \
# 0                       97.4                    96.1               3701
# 1                       97.1                    95.7               2850
# 2                       90.9                    85.7               3053
# 3                       87.5                    87.5               3557
# 4                       95.3                    95.3               3494
# ...                      ...                     ...                ...
# 1116                    97.4                    79.5               3245
# 1117                    98.3                    96.7               4936
# 1118                    89.9                    85.5               4047
# 1119                    95.5                    90.9               4542
# 1120                    96.6                    89.7               3800
#
#      basic_monthly_median gross_monthly_mean gross_monthly_median  \
# 0                    3200               3727                 3350
# 1                    2700               2938                 2700
# 2                    3000               3214                 3000
# 3                    3400               3615                 3400
# 4                    3500               3536                 3500
# ...                   ...                ...                  ...
# 1116                 3200               3381                 3300
# 1117                 4800               5030                 4800
# 1118                 4000               4141                 4000
# 1119                 4500               4778                 4700
# 1120                 3801               3842                 3875
#
#      gross_mthly_25_percentile gross_mthly_75_percentile
# 0                         2900                      4000
# 1                         2700                      2900
# 2                         2700                      3500
# 3                         3000                      4100
# 4                         3100                      3816
# ...                        ...                       ...
# 1116                      3025                      3500
# 1117                      4400                      5414
# 1118                      3750                      4500
# 1119                      3900                      5000
# 1120                      3430                      4200
#
# [1121 rows x 12 columns]

# %%
#2
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1121 entries, 0 to 1120
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   year                       1121 non-null   int64
#  1   university                 1121 non-null   object
#  2   school                     1121 non-null   object
#  3   degree                     1121 non-null   object
#  4   employment_rate_overall    1121 non-null   object
#  5   employment_rate_ft_perm    1121 non-null   object
#  6   basic_monthly_mean         1121 non-null   object
#  7   basic_monthly_median       1121 non-null   object
#  8   gross_monthly_mean         1121 non-null   object
#  9   gross_monthly_median       1121 non-null   object
#  10  gross_mthly_25_percentile  1121 non-null   object
#  11  gross_mthly_75_percentile  1121 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 105.2+ KB

# %%
data.head()
# Out:
#    year                        university  \
# 0  2013  Nanyang Technological University
# 1  2013  Nanyang Technological University
# 2  2013  Nanyang Technological University
# 3  2013  Nanyang Technological University
# 4  2013  Nanyang Technological University
#
#                                           school  \
# 0  College of Business (Nanyang Business School)
# 1  College of Business (Nanyang Business School)
# 2  College of Business (Nanyang Business School)
# 3  College of Business (Nanyang Business School)
# 4                         College of Engineering
#
#                                         degree employment_rate_overall  \
# 0                     Accountancy and Business                    97.4
# 1  Accountancy (3-yr direct Honours Programme)                    97.1
# 2     Business (3-yr direct Honours Programme)                    90.9
# 3                       Business and Computing                    87.5
# 4                        Aerospace Engineering                    95.3
#
#   employment_rate_ft_perm basic_monthly_mean basic_monthly_median  \
# 0                    96.1               3701                 3200
# 1                    95.7               2850                 2700
# 2                    85.7               3053                 3000
# 3                    87.5               3557                 3400
# 4                    95.3               3494                 3500
#
#   gross_monthly_mean gross_monthly_median gross_mthly_25_percentile  \
# 0               3727                 3350                      2900
# 1               2938                 2700                      2700
# 2               3214                 3000                      2700
# 3               3615                 3400                      3000
# 4               3536                 3500                      3100
#
#   gross_mthly_75_percentile
# 0                      4000
# 1                      2900
# 2                      3500
# 3                      4100
# 4                      3816

# %%
data.shape
# Out:
# (1121, 12)

# %%
data['university'].unique()
# Out:
# array(['Nanyang Technological University',
#        'National University of Singapore',
#        'Singapore Management University',
#        'Singapore Institute of Technology',
#        'Singapore University of Technology and Design',
#        'Singapore University of Social Sciences'], dtype=object)

# %%
#3 Housekeeping things
replace_info = {
    'Nanyang Technological University': 'NTU',
    'National University of Singapore': 'NUS',
    'Singapore Management University': 'SMU',
    'Singapore Institute of Technology': 'SIT',
    'Singapore University of Technology and Design': 'SUTD',
    'Singapore University of Social Sciences': 'SUSS'}
new_type_info = {
    'year': 'category',
    'university': 'category',
    'school': 'category',
    'degree': 'category',
    'basic_monthly_median': 'float'
}
columns_to_keep = [
    'year',
    'university',
    'school',
    'degree',
    'basic_monthly_median']

# %%
data.replace('na', np.nan, inplace=True) #replace na with nan

# %%
data = data[columns_to_keep] #keeping only basic_monthly_median

# %%
data.replace(to_replace=replace_info, inplace=True) #shorten uni names
# Out:
# C:\Users\Xavier\AppData\Local\Temp\ipykernel_11904\3065060031.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.replace(to_replace=replace_info, inplace=True)

# %%
data = data.astype(new_type_info) #change types

# %%
#removing nan
data.dropna(axis=1, inplace=True)

# %%
#masking for universities to isolate their data
data[data['year'] == 2013]
# Out:
#     year university                                             degree
# 0   2013        NTU                           Accountancy and Business
# 1   2013        NTU        Accountancy (3-yr direct Honours Programme)
# 2   2013        NTU           Business (3-yr direct Honours Programme)
# 3   2013        NTU                             Business and Computing
# 4   2013        NTU                              Aerospace Engineering
# ..   ...        ...                                                ...
# 80  2013        SMU  Information Systems Management (4-years progra...
# 81  2013        SMU                Social Sciences (4-years programme)
# 82  2013        SMU  Social Sciences (4-years programme) Cum Laude ...
# 83  2013        SMU                          Law (4-years programme) #
# 84  2013        SMU      Law (4-years programme) Cum Laude and above #
#
# [85 rows x 3 columns]
